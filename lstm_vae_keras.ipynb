# %%
from keras import objectives, backend as K
from keras.layers import Bidirectional, Dense, Embedding, Input, Lambda, LSTM, RepeatVector, TimeDistributed
from keras.models import Model
import keras
from keras.layers import Input, Dense, Lambda, Layer
import numpy as np
import uuid
from nltk.tokenize import sent_tokenize
from gensim.models import KeyedVectors
import pickle
import itertools
# Out:
# C:\Users\Vinod\Anaconda2\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Users\Vinod\Anaconda2\envs\tensorflow\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
class VAE(object):
    
    def _build_decoder(self, encoded, vocab_size, max_length):
        repeated_context = RepeatVector(max_length)(encoded)

        h = LSTM(500, return_sequences=True, name='dec_lstm_1')(repeated_context)
        h = LSTM(500, return_sequences=True, name='dec_lstm_2')(h)

        decoded = TimeDistributed(Dense(vocab_size, activation='softmax'), name='decoded_mean')(h)

        return decoded
    def _build_encoder(self, x, latent_rep_size=100, max_length=300, epsilon_std=0.01):
        h = Bidirectional(LSTM(500, return_sequences=True, name='lstm_1'), merge_mode='concat')(x)
        h = Bidirectional(LSTM(500, return_sequences=False, name='lstm_2'), merge_mode='concat')(h)
        h = Dense(435, activation='relu', name='dense_1')(h)

        def sampling(args):
            z_mean_, z_log_var_ = args
            batch_size = K.shape(z_mean_)[0]
            epsilon = K.random_normal(shape=(batch_size, latent_rep_size), mean=0., stddev=epsilon_std)
            return z_mean_ + K.exp(z_log_var_ / 2) * epsilon

        z_mean = Dense(latent_rep_size, name='z_mean', activation='linear')(h)
        z_log_var = Dense(latent_rep_size, name='z_log_var', activation='linear')(h)

        def vae_loss(x, x_decoded_mean):
            x = K.flatten(x)
            x_decoded_mean = K.flatten(x_decoded_mean)
            xent_loss = max_length * objectives.binary_crossentropy(x, x_decoded_mean)
            kl_loss = - 0.5 * K.mean(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
            return xent_loss + kl_loss

        return (vae_loss, Lambda(sampling, output_shape=(latent_rep_size,), name='lambda')([z_mean, z_log_var]))


    def create(self, vocab_size=1000, max_length=50, latent_rep_size=100):
        self.encoder = None
        self.decoder = None
        self.autoencoder = None

        x = Input(shape=(max_length,))
        x_embed = Embedding(vocab_size, 64, input_length=max_length)(x)

        vae_loss, encoded = self._build_encoder(x_embed, latent_rep_size=latent_rep_size, max_length=max_length)
        self.encoder = Model(inputs=x, outputs=encoded)

        encoded_input = Input(shape=(latent_rep_size,))


        decoded = self._build_decoder(encoded_input, vocab_size, max_length)
        self.decoder = Model(encoded_input, decoded)

        self.autoencoder = Model(inputs=x, outputs=[self._build_decoder(encoded, vocab_size, max_length)])
        self.autoencoder.compile(optimizer='Adam',
                                 loss=[vae_loss],
                                 metrics=['accuracy'])

# %%
MAX_LENGTH
# Out:
# 50

# %%
from keras.callbacks import ModelCheckpoint
from keras.datasets import imdb
from keras.preprocessing.sequence import pad_sequences
import numpy as np
import os
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

NUM_WORDS=1000
MAX_LENGTH=15
VALIDATION_SPLIT =.3
_EOS = "endofsent"

def sent_parse(sentences,tokenizer=None,build_indices=True):
    if build_indices:
        tokenizer = Tokenizer(nb_words=NUM_WORDS)
        tokenizer.fit_on_texts(sentences)
        sequences = tokenizer.texts_to_sequences(sentences)
        word_index = tokenizer.word_index
        print('Found %s unique tokens.' % len(word_index))
        data = pad_sequences(sequences, maxlen=MAX_LENGTH)
        indices = np.arange(data.shape[0])
        np.random.shuffle(indices)
        data = data[indices]
    else:
        sequences = tokenizer.texts_to_sequences(sentences)
        data = pad_sequences(sequences, maxlen=MAX_LENGTH)
        indices = np.arange(data.shape[0])
        np.random.shuffle(indices)
        data = data[indices]
    return tokenizer,data


    

def find_similar_encoding(sent_vect):
    all_cosine = []
    for sent in sent_encoded:
        result = 1 - spatial.distance.cosine(sent_vect, sent)
        all_cosine.append(result)
    data_array = np.array(all_cosine)
    maximum = data_array.argsort()[-3:][::-1][1]
    new_vec = sent_encoded[maximum]
    return new_vec


def interpolate_b_points(point_one, point_two, num):
    dist_vec = point_two - point_one
    sample = np.linspace(0, 1, num, endpoint = True)
    hom_sample = []
    for s in sample:
        hom_sample.append(point_one + s * dist_vec)
    return hom_sample


def sent_2_sent(sent1,sent2, model,tokenizer=None):
    _,a = sent_parse([sent1],tokenizer,build_indices=False)
    _,b = sent_parse([sent2],tokenizer,build_indices=False)
    encode_a = model.encoder.predict(a)
    encode_b = model.encoder.predict(b)
    test_hom = interpolate_b_points(encode_a, encode_b, 100)
    index_word = {v: k for k, v in tokenizer.word_index.items()}

    for point in test_hom:
        words=[]
        deco=model.decoder.predict(point)
        #print(deco)
        for seq in deco[0]:
            words.append(index_word[np.argmax(seq)])
            words.append(' ')
        print(''.join(words))
       
        #print_sentence_with_w2v(p,index_word)

# %%
import nltk
from nltk.corpus import brown
def split_into_sent (text):
    strg = ''
    for word in text:
        strg += word
        strg += ' '
    strg_cleaned = strg.lower()
    for x in ['\n','"',"!", '#','$','%','&','(',')','*','+',',','-','/',':',';','<','=','>','?','@','[','^',']','_','`','{','|','}','~','\t']:
        strg_cleaned = strg_cleaned.replace(x, '')
    sentences = sent_tokenize(strg_cleaned)
    return sentences

fiction_text=brown.words(categories=['fiction','humor', 'learned', 'lore', 'mystery', 'news'])
sents=split_into_sent(fiction_text)
# Out:
# 23515

# %%
###### APT Text#############

#with open('C:\\Users\\Vinod\\projects\\keras\\APT_sanitized.txt',"r",encoding='utf-8') as f:
#    texts=f.readlines()


#eostxts=[]
#for txt in texts:
#    eostxts.append(txt + " " + _EOS)



tokenizer,data=sent_parse(sents)

nb_validation_samples = int(VALIDATION_SPLIT * data.shape[0])

X_train = data[:-nb_validation_samples]
X_test = data[-nb_validation_samples:]





print("Training data")
print(X_train.shape)

print("Number of words:")
print(len(np.unique(np.hstack(X_train))))



temp = np.zeros((X_train.shape[0], MAX_LENGTH, NUM_WORDS))
temp[np.expand_dims(np.arange(X_train.shape[0]), axis=0).reshape(X_train.shape[0], 1), np.repeat(np.array([np.arange(MAX_LENGTH)]), X_train.shape[0], axis=0), X_train] = 1

X_train_one_hot = temp

temp = np.zeros((X_test.shape[0], MAX_LENGTH, NUM_WORDS))
temp[np.expand_dims(np.arange(X_test.shape[0]), axis=0).reshape(X_test.shape[0], 1), np.repeat(np.array([np.arange(MAX_LENGTH)]), X_test.shape[0], axis=0), X_test] = 1

x_test_one_hot = temp

def create_model_checkpoint(dir, model_name):
    filepath = dir + '/' + \
                model_name
               #model_name + "-{epoch:02d}-{val_decoded_mean_acc:.2f}-{val_pred_loss:.2f}.h5"
    directory = os.path.dirname(filepath)

    try:
        os.stat(directory)
    except:
        os.mkdir(directory)

    checkpointer = ModelCheckpoint(filepath=filepath,
                                   verbose=1,
                                   save_best_only=False)

    return checkpointer
# Out:
# C:\Users\Vinod\Anaconda2\envs\tensorflow\lib\site-packages\keras\preprocessing\text.py:157: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '
# Found 32683 unique tokens.
# Training data
# (16461, 15)
# Number of words:
# 1000

# %%
index_word = {v: k for k, v in tokenizer.word_index.items()}
index_word
# Out:
# {1: 'the',
#  2: 'of',
#  3: 'and',
#  4: 'to',
#  5: 'a',
#  6: 'in',
#  7: 'was',
#  8: 'that',
#  9: 'is',
#  10: 'for',
#  11: 'he',
#  12: 'it',
#  13: "''",
#  14: 'with',
#  15: 'as',
#  16: 'on',
#  17: 'be',
#  18: 'his',
#  19: 'at',
#  20: 'by',
#  21: 'had',
#  22: 'this',
#  23: 'from',
#  24: 'not',
#  25: 'i',
#  26: 'or',
#  27: 'are',
#  28: 'but',
#  29: 'an',
#  30: 'were',
#  31: 'have',
#  32: 'they',
#  33: 'which',
#  34: 'one',
#  35: 'her',
#  36: 'there',
#  37: 'she',
#  38: 'would',
#  39: 'all',
#  40: 'been',
#  41: 'you',
#  42: 'their',
#  43: 'when',
#  44: 'him',
#  45: 'we',
#  46: 'has',
#  47: 'said',
#  48: 'more',
#  49: 'will',
#  50: 'who',
#  51: 'no',
#  52: 'if',
#  53: 'out',
#  54: 'up',
#  55: 'af',
#  56: 'about',
#  57: 'into',
#  58: 'what',
#  59: 'so',
#  60: 'some',
#  61: 'than',
#  62: 'its',
#  63: 'them',
#  64: 'only',
#  65: 'two',
#  66: 'could',
#  67: 'these',
#  68: 'can',
#  69: 'other',
#  70: 'time',
#  71: 'first',
#  72: 'then',
#  73: 'new',
#  74: 'may',
#  75: 'over',
#  76: 'such',
#  77: 'now',
#  78: 'any',
#  79: 'like',
#  80: 'do',
#  81: 'after',
#  82: 'made',
#  83: 'most',
#  84: 'even',
#  85: 'also',
#  86: 'man',
#  87: 'before',
#  88: 'did',
#  89: 'where',
#  90: 'my',
#  91: 'each',
#  92: 'back',
#  93: 'must',
#  94: 'me',
#  95: 'through',
#  96: 'many',
#  97: 'state',
#  98: 'much',
#  99: 'mrs',
#  100: 'should',
#  101: 'our',
#  102: 'years',
#  103: 'down',
#  104: 'people',
#  105: 'mr',
#  106: 'way',
#  107: 'here',
#  108: 'well',
#  109: '1',
#  110: 'because',
#  111: 'very',
#  112: 'those',
#  113: 'both',
#  114: 'just',
#  115: 'get',
#  116: 'how',
#  117: 'still',
#  118: 'used',
#  119: 'between',
#  120: 'work',
#  121: 'three',
#  122: 'another',
#  123: 'same',
#  124: 'last',
#  125: 'little',
#  126: 'school',
#  127: 'see',
#  128: 'under',
#  129: 'off',
#  130: 'too',
#  131: 'since',
#  132: 'while',
#  133: 'might',
#  134: 'make',
#  135: 'home',
#  136: 'house',
#  137: '2',
#  138: 'good',
#  139: 'long',
#  140: 'own',
#  141: 'men',
#  142: 'being',
#  143: 'go',
#  144: 'however',
#  145: 'day',
#  146: 'found',
#  147: 'against',
#  148: 'know',
#  149: 'old',
#  150: 'during',
#  151: 'came',
#  152: 'again',
#  153: 'high',
#  154: 'never',
#  155: 'few',
#  156: 'number',
#  157: 'system',
#  158: 'around',
#  159: 'come',
#  160: 'great',
#  161: 'year',
#  162: 'take',
#  163: 'went',
#  164: 'use',
#  165: 'place',
#  166: 'right',
#  167: 'world',
#  168: 'life',
#  169: 'without',
#  170: 'your',
#  171: 'small',
#  172: 'left',
#  173: 'told',
#  174: 'got',
#  175: 'once',
#  176: 'room',
#  177: 'thought',
#  178: 'general',
#  179: 'always',
#  180: 'children',
#  181: 'himself',
#  182: 'say',
#  183: 'part',
#  184: 'us',
#  185: 'upon',
#  186: 'case',
#  187: 'point',
#  188: 'group',
#  189: 'until',
#  190: 'hand',
#  191: 'away',
#  192: 'four',
#  193: 'white',
#  194: 'given',
#  195: "don't",
#  196: 'city',
#  197: 'set',
#  198: 'course',
#  199: 'fact',
#  200: 'put',
#  201: 'social',
#  202: 'second',
#  203: 'every',
#  204: 'called',
#  205: 'asked',
#  206: 'states',
#  207: 'though',
#  208: '3',
#  209: 'took',
#  210: 'something',
#  211: 'enough',
#  212: 'later',
#  213: 'american',
#  214: 'far',
#  215: 'possible',
#  216: 'end',
#  217: 'does',
#  218: 'less',
#  219: 'night',
#  220: 'public',
#  221: 'president',
#  222: 'next',
#  223: 'head',
#  224: 'think',
#  225: 'per',
#  226: 'knew',
#  227: 's',
#  228: "didn't",
#  229: 'information',
#  230: 'early',
#  231: 'among',
#  232: 'members',
#  233: 'water',
#  234: 'john',
#  235: 'almost',
#  236: 'why',
#  237: 'different',
#  238: 'days',
#  239: 'going',
#  240: 'find',
#  241: 'area',
#  242: 'order',
#  243: 'form',
#  244: 'toward',
#  245: 'give',
#  246: 'certain',
#  247: 'better',
#  248: 'rather',
#  249: 'along',
#  250: 'often',
#  251: 'felt',
#  252: 'large',
#  253: 'national',
#  254: 'important',
#  255: 'yet',
#  256: 'local',
#  257: 'seemed',
#  258: 'looked',
#  259: 'church',
#  260: 'u',
#  261: 'big',
#  262: 'family',
#  263: 'company',
#  264: 'face',
#  265: 'several',
#  266: 'government',
#  267: 'things',
#  268: 'door',
#  269: 'law',
#  270: 'c',
#  271: 'thus',
#  272: 'become',
#  273: 'nothing',
#  274: 'problem',
#  275: 'five',
#  276: 'week',
#  277: 'm',
#  278: 'side',
#  279: 'want',
#  280: 'open',
#  281: 'look',
#  282: 'federal',
#  283: 'present',
#  284: 'p',
#  285: 'within',
#  286: 'began',
#  287: 'interest',
#  288: 'example',
#  289: 'business',
#  290: 'line',
#  291: 'turned',
#  292: 'program',
#  293: 'saw',
#  294: 'means',
#  295: 'although',
#  296: 'young',
#  297: 'light',
#  298: 'let',
#  299: 'car',
#  300: 'court',
#  301: 'eyes',
#  302: 'taken',
#  303: 'united',
#  304: 'study',
#  305: 'least',
#  306: 'miss',
#  307: 'best',
#  308: 'office',
#  309: 'thing',
#  310: 'matter',
#  311: 'power',
#  312: 'education',
#  313: "it's",
#  314: 'war',
#  315: 'past',
#  316: 'surface',
#  317: 'whole',
#  318: 'show',
#  319: 'money',
#  320: 'done',
#  321: 'probably',
#  322: 'mind',
#  323: 'hands',
#  324: 'major',
#  325: 'e',
#  326: 'need',
#  327: 'name',
#  328: 'either',
#  329: 'ever',
#  330: 'across',
#  331: 'times',
#  332: 'street',
#  333: 'became',
#  334: 'held',
#  335: 'word',
#  336: 'seen',
#  337: 'tell',
#  338: 'others',
#  339: 'rate',
#  340: 'sense',
#  341: 'itself',
#  342: 'today',
#  343: 'above',
#  344: 'words',
#  345: '4',
#  346: 'feet',
#  347: 'figure',
#  348: 'together',
#  349: 'kind',
#  350: 'seems',
#  351: 'anything',
#  352: 'quite',
#  353: 'half',
#  354: 'college',
#  355: '5',
#  356: 'economic',
#  357: 'front',
#  358: 'result',
#  359: 'wife',
#  360: 'service',
#  361: 'lines',
#  362: 'gave',
#  363: 'perhaps',
#  364: 'whether',
#  365: 'schools',
#  366: 'question',
#  367: 'behind',
#  368: 'table',
#  369: 'field',
#  370: 'cost',
#  371: 'value',
#  372: 'expected',
#  373: 'heard',
#  374: 'air',
#  375: 'data',
#  376: 'police',
#  377: 'minutes',
#  378: 'b',
#  379: 'action',
#  380: 'type',
#  381: 'sometimes',
#  382: 'making',
#  383: 'cent',
#  384: 'following',
#  385: 'change',
#  386: 'stage',
#  387: 'boy',
#  388: 'moment',
#  389: 'evidence',
#  390: 'already',
#  391: 'having',
#  392: 'really',
#  393: 'woman',
#  394: 'child',
#  395: "i'm",
#  396: 'process',
#  397: 'policy',
#  398: 'various',
#  399: 'free',
#  400: 'country',
#  401: 'common',
#  402: 'act',
#  403: 'areas',
#  404: 'special',
#  405: 'york',
#  406: 'individual',
#  407: 'level',
#  408: 'body',
#  409: 'meeting',
#  410: 'road',
#  411: "'",
#  412: 'known',
#  413: 'keep',
#  414: 'whose',
#  415: 'increase',
#  416: 'red',
#  417: 'third',
#  418: 'center',
#  419: 'total',
#  420: 'values',
#  421: 'effect',
#  422: 'brought',
#  423: 'pressure',
#  424: 'period',
#  425: 'usually',
#  426: 'therefore',
#  427: 'further',
#  428: 'university',
#  429: 'trial',
#  430: 'north',
#  431: 'costs',
#  432: 'force',
#  433: 'near',
#  434: '10',
#  435: 'help',
#  436: 'months',
#  437: 'age',
#  438: 'run',
#  439: 'problems',
#  440: 'able',
#  441: 'conditions',
#  442: 'short',
#  443: 'committee',
#  444: 'board',
#  445: 'control',
#  446: 'society',
#  447: 'turn',
#  448: 'girl',
#  449: 'material',
#  450: 'cases',
#  451: 'ago',
#  452: 'top',
#  453: 'wanted',
#  454: 'similar',
#  455: 'real',
#  456: 'cannot',
#  457: 'labor',
#  458: 'industry',
#  459: 'experience',
#  460: 'six',
#  461: 'single',
#  462: 'available',
#  463: 'mean',
#  464: 'job',
#  465: 'section',
#  466: 'plan',
#  467: 'j',
#  468: 'students',
#  469: 'higher',
#  470: 'party',
#  471: 'reaction',
#  472: 'clear',
#  473: 'basis',
#  474: 'reason',
#  475: 'sure',
#  476: 'county',
#  477: 'close',
#  478: 'union',
#  479: 'results',
#  480: 'low',
#  481: 'death',
#  482: 'themselves',
#  483: 'south',
#  484: 'seem',
#  485: 'temperature',
#  486: 'stood',
#  487: 'development',
#  488: 'full',
#  489: 't',
#  490: 'farm',
#  491: 'black',
#  492: 'required',
#  493: 'necessary',
#  494: 'morning',
#  495: 'soon',
#  496: 'dr',
#  497: 'started',
#  498: 'position',
#  499: 'paper',
#  500: 'd',
#  501: 'bill',
#  502: 'true',
#  503: 'call',
#  504: 'women',
#  505: 'n',
#  506: 'leave',
#  507: 'feel',
#  508: 'political',
#  509: 'added',
#  510: 'situation',
#  511: 'play',
#  512: 'says',
#  513: 'likely',
#  514: 'district',
#  515: 'community',
#  516: 'alone',
#  517: "that's",
#  518: 'human',
#  519: 'provide',
#  520: 'million',
#  521: 'believe',
#  522: 'hard',
#  523: 'range',
#  524: 'outside',
#  525: 'gone',
#  526: 'shown',
#  527: 'view',
#  528: 'voice',
#  529: 'future',
#  530: 'washington',
#  531: 'finally',
#  532: 'normal',
#  533: 'space',
#  534: 'late',
#  535: 'west',
#  536: 'methods',
#  537: 'statement',
#  538: 'systems',
#  539: 'hotel',
#  540: 'land',
#  541: 'ten',
#  542: 'mother',
#  543: 'river',
#  544: 'coming',
#  545: 'kept',
#  546: 'history',
#  547: 'function',
#  548: 'town',
#  549: 'class',
#  550: 'stress',
#  551: 'including',
#  552: 'population',
#  553: 'taking',
#  554: 'department',
#  555: 'strong',
#  556: 'basic',
#  557: 'complete',
#  558: 'tried',
#  559: 'greater',
#  560: 'support',
#  561: 'care',
#  562: 'god',
#  563: 'plane',
#  564: 'tax',
#  565: 'aj',
#  566: 'amount',
#  567: "couldn't",
#  568: 'except',
#  569: 'f',
#  570: 'cut',
#  571: 'developed',
#  572: 'am',
#  573: 'longer',
#  574: 'administration',
#  575: 'issue',
#  576: 'r',
#  577: 'decided',
#  578: 'building',
#  579: 'needed',
#  580: 'wrote',
#  581: 'list',
#  582: 'bad',
#  583: 'showed',
#  584: 'dark',
#  585: 'getting',
#  586: 'hold',
#  587: 'defense',
#  588: 'actually',
#  589: 'described',
#  590: 'central',
#  591: 'using',
#  592: "i'll",
#  593: 'treatment',
#  594: 'below',
#  595: '6',
#  596: 'person',
#  597: 'secretary',
#  598: 'international',
#  599: 'trade',
#  600: 'dead',
#  601: 'reached',
#  602: 'stock',
#  603: 'passed',
#  604: 'everything',
#  605: 'record',
#  606: 'hour',
#  607: 'points',
#  608: 'growth',
#  609: 'training',
#  610: 'nearly',
#  611: 'picture',
#  612: 'modern',
#  613: 'moved',
#  614: 'increased',
#  615: 'return',
#  616: 'final',
#  617: 'volume',
#  618: 'living',
#  619: 'east',
#  620: 'particularly',
#  621: 'activity',
#  622: 'club',
#  623: 'difference',
#  624: 'followed',
#  625: 'sort',
#  626: 'game',
#  627: 'boys',
#  628: 'particular',
#  629: 'theory',
#  630: 'received',
#  631: 'l',
#  632: '8',
#  633: 'read',
#  634: 'reported',
#  635: 'kennedy',
#  636: 'equipment',
#  637: 'anode',
#  638: 'fire',
#  639: 'earlier',
#  640: 'test',
#  641: 'questions',
#  642: 'live',
#  643: 'effort',
#  644: 'floor',
#  645: 'foreign',
#  646: 'religious',
#  647: 'considered',
#  648: 'terms',
#  649: 'cold',
#  650: 'husband',
#  651: 'food',
#  652: 'index',
#  653: 'hours',
#  654: "can't",
#  655: 'h',
#  656: 'suddenly',
#  657: 'gas',
#  658: 'involved',
#  659: 'changes',
#  660: 'analysis',
#  661: 'method',
#  662: 'groups',
#  663: 'move',
#  664: 'image',
#  665: 'private',
#  666: '1960',
#  667: 'wall',
#  668: 'ball',
#  669: '0',
#  670: 'generally',
#  671: 'merely',
#  672: 'series',
#  673: 'firm',
#  674: 'st',
#  675: 'appear',
#  676: 'hundred',
#  677: 'feeling',
#  678: 'beyond',
#  679: 'nor',
#  680: 'lower',
#  681: 'forms',
#  682: 'charge',
#  683: 'according',
#  684: 'report',
#  685: 'degree',
#  686: 'reading',
#  687: 'sound',
#  688: 'inside',
#  689: 'ground',
#  690: 'clearly',
#  691: 'else',
#  692: 'especially',
#  693: 'fall',
#  694: 'trouble',
#  695: 'former',
#  696: 'hear',
#  697: 'immediately',
#  698: 'direct',
#  699: 'somewhat',
#  700: '15',
#  701: 'indeed',
#  702: 'length',
#  703: 'walked',
#  704: 'simply',
#  705: 'george',
#  706: 'deal',
#  707: 'attention',
#  708: 'countries',
#  709: 'happened',
#  710: 'simple',
#  711: 'market',
#  712: 'sat',
#  713: 'teeth',
#  714: 'window',
#  715: 'cells',
#  716: 'william',
#  717: 'persons',
#  718: 'instead',
#  719: 'lost',
#  720: 'indicated',
#  721: 'meet',
#  722: 'makes',
#  723: 'girls',
#  724: 'medical',
#  725: 'couple',
#  726: 'w',
#  727: '1958',
#  728: 'pay',
#  729: 'needs',
#  730: 'subject',
#  731: 'yesterday',
#  732: 'programs',
#  733: 'concerned',
#  734: 'direction',
#  735: 'specific',
#  736: 'meaning',
#  737: 'talk',
#  738: 'shall',
#  739: 'bring',
#  740: 'square',
#  741: 'father',
#  742: 'hit',
#  743: 'larger',
#  744: 'size',
#  745: 'price',
#  746: 'working',
#  747: 'nature',
#  748: 'daily',
#  749: 'average',
#  750: 'looking',
#  751: 'due',
#  752: 'miles',
#  753: 'appeared',
#  754: 'rates',
#  755: 'entire',
#  756: 'century',
#  757: 'film',
#  758: 'closed',
#  759: 'recent',
#  760: 'march',
#  761: 'gun',
#  762: 'idea',
#  763: 'served',
#  764: 'obtained',
#  765: 'weeks',
#  766: 'military',
#  767: 'types',
#  768: 'member',
#  769: 'trying',
#  770: 'brown',
#  771: 'written',
#  772: 'hospital',
#  773: 'addition',
#  774: 'mass',
#  775: 'workers',
#  776: 'continued',
#  777: 'rest',
#  778: 'throughout',
#  779: 'distribution',
#  780: 'platform',
#  781: 'ready',
#  782: 'apparently',
#  783: 'paid',
#  784: 'sunday',
#  785: 'chief',
#  786: 'soviet',
#  787: 'spirit',
#  788: 'station',
#  789: 'ways',
#  790: 'month',
#  791: 'beginning',
#  792: 'start',
#  793: 'directly',
#  794: 'behavior',
#  795: 'effective',
#  796: 'married',
#  797: 'sales',
#  798: 'aid',
#  799: 'noted',
#  800: 'forces',
#  801: 'efforts',
#  802: 'love',
#  803: 'answer',
#  804: 'corner',
#  805: 'remember',
#  806: 'g',
#  807: 'latter',
#  808: 'bed',
#  809: 'hall',
#  810: 'association',
#  811: 'purpose',
#  812: 'council',
#  813: 'afternoon',
#  814: '100',
#  815: 'led',
#  816: 'eight',
#  817: 'yes',
#  818: 'vocational',
#  819: 'met',
#  820: 'main',
#  821: 'anyone',
#  822: 'consider',
#  823: "you're",
#  824: 'middle',
#  825: 'scene',
#  826: 'lay',
#  827: 'lot',
#  828: 'cattle',
#  829: 'additional',
#  830: 'congress',
#  831: 'hot',
#  832: "wasn't",
#  833: 'personal',
#  834: 'parts',
#  835: 'patient',
#  836: 'step',
#  837: 'heart',
#  838: 'energy',
#  839: 'try',
#  840: 'art',
#  841: 'radiation',
#  842: 'sections',
#  843: 'numbers',
#  844: 'ask',
#  845: 'doctor',
#  846: 'unit',
#  847: 'monday',
#  848: 'opened',
#  849: 'research',
#  850: '12',
#  851: 'summer',
#  852: '20',
#  853: '7',
#  854: 'figures',
#  855: 'distance',
#  856: 'difficult',
#  857: 'certainly',
#  858: 'hope',
#  859: 'carried',
#  860: 'applied',
#  861: 'failure',
#  862: 'names',
#  863: 'relations',
#  864: '30',
#  865: 'ones',
#  866: 'democratic',
#  867: 'sent',
#  868: 'fine',
#  869: 'de',
#  870: 'parents',
#  871: 'knowledge',
#  872: 'fixed',
#  873: 'expect',
#  874: 'stopped',
#  875: 'supply',
#  876: 'christian',
#  877: 'pattern',
#  878: 'poet',
#  879: 'son',
#  880: 'wait',
#  881: 'returned',
#  882: 'doing',
#  883: 'procedure',
#  884: 'related',
#  885: 'dinner',
#  886: 'season',
#  887: 'marriage',
#  888: 'music',
#  889: 'exactly',
#  890: 'oil',
#  891: 'physical',
#  892: 'steps',
#  893: 'henry',
#  894: 'limited',
#  895: 'address',
#  896: 'based',
#  897: 'elements',
#  898: 'influence',
#  899: 'manager',
#  900: 'friends',
#  901: 'pain',
#  902: 'cell',
#  903: 'cause',
#  904: 'manner',
#  905: 'shot',
#  906: 'annual',
#  907: 'radio',
#  908: 'student',
#  909: 'america',
#  910: 'neither',
#  911: 'mouth',
#  912: 'account',
#  913: 'products',
#  914: 'effects',
#  915: 'kitchen',
#  916: 'british',
#  917: 'french',
#  918: 'language',
#  919: 'actual',
#  920: 'importance',
#  921: 'wine',
#  922: 'director',
#  923: 'companies',
#  924: 'horse',
#  925: 'suggested',
#  926: 'poor',
#  927: 'army',
#  928: 'treated',
#  929: 'completely',
#  930: 'plant',
#  931: 'opportunity',
#  932: 'easy',
#  933: 'ran',
#  934: 'straight',
#  935: 'lead',
#  936: 'earth',
#  937: 'hair',
#  938: 'religion',
#  939: 'dictionary',
#  940: 'jury',
#  941: 'election',
#  942: 'services',
#  943: 'operation',
#  944: 'james',
#  945: 'provided',
#  946: 'rules',
#  947: 'team',
#  948: 'relatively',
#  949: "wouldn't",
#  950: 'walk',
#  951: 'stand',
#  952: 'conference',
#  953: '1959',
#  954: 'comes',
#  955: 'heavy',
#  956: 'understand',
#  957: 'established',
#  958: 'unless',
#  959: 'appears',
#  960: 'include',
#  961: 'wide',
#  962: 'drive',
#  963: 'waiting',
#  964: 'condition',
#  965: "i've",
#  966: 'book',
#  967: 'respect',
#  968: 'success',
#  969: 'complex',
#  970: 'funds',
#  971: 'texas',
#  972: 'plans',
#  973: 'doubt',
#  974: 'capital',
#  975: 'subjects',
#  976: 'raised',
#  977: 'determined',
#  978: 'movement',
#  979: 'techniques',
#  980: 'approach',
#  981: 'studies',
#  982: 'reach',
#  983: 'becomes',
#  984: 'extent',
#  985: 'judge',
#  986: 'jr',
#  987: 'health',
#  988: 'tuesday',
#  989: 'blue',
#  990: '1961',
#  991: 'worth',
#  992: 'whom',
#  993: 'rise',
#  994: 'caused',
#  995: 'nations',
#  996: 'running',
#  997: 'ahead',
#  998: 'western',
#  999: 'evening',
#  1000: 'q',
#  ...}

# %% [markdown]
# print(indices[0])

# %%
from keras.callbacks import TensorBoard
from time import time
def train():
    model = VAE()
    model.create(vocab_size=NUM_WORDS, max_length=MAX_LENGTH)
    
    tensorboard = TensorBoard(log_dir="logs/{}".format(time()))
    checkpointer = create_model_checkpoint('models', 'rnn_ae')
    
    model.autoencoder.fit(x=X_train, y={'decoded_mean': X_train_one_hot},
                          batch_size=100, epochs=10, callbacks=[checkpointer,tensorboard],
                          validation_data=(X_test, {'decoded_mean': x_test_one_hot}))
    return model

# %%
model=train()
# Out:
# Train on 16461 samples, validate on 7054 samples
# Epoch 1/10
# 16400/16461 [============================>.] - ETA: 0s - loss: 0.0807 - acc: 0.3132
# Epoch 00001: saving model to models/rnn_ae
# 16461/16461 [==============================] - 81s 5ms/step - loss: 0.0806 - acc: 0.3132 - val_loss: 0.0727 - val_acc: 0.3210
# Epoch 2/10
# 16400/16461 [============================>.] - ETA: 0s - loss: 0.0703 - acc: 0.3396
# Epoch 00002: saving model to models/rnn_ae
# 16461/16461 [==============================] - 75s 5ms/step - loss: 0.0703 - acc: 0.3395 - val_loss: 0.0699 - val_acc: 0.3394
# Epoch 3/10
# 16400/16461 [============================>.] - ETA: 0s - loss: 0.0694 - acc: 0.3427
# Epoch 00003: saving model to models/rnn_ae
# 16461/16461 [==============================] - 76s 5ms/step - loss: 0.0695 - acc: 0.3425 - val_loss: 0.0694 - val_acc: 0.3415
# Epoch 4/10
# 16400/16461 [============================>.] - ETA: 0s - loss: 0.0689 - acc: 0.3440
# Epoch 00004: saving model to models/rnn_ae
# 16461/16461 [==============================] - 78s 5ms/step - loss: 0.0689 - acc: 0.3441 - val_loss: 0.0695 - val_acc: 0.3440
# Epoch 5/10
# 16400/16461 [============================>.] - ETA: 0s - loss: 0.0687 - acc: 0.3447
# Epoch 00005: saving model to models/rnn_ae
# 16461/16461 [==============================] - 76s 5ms/step - loss: 0.0687 - acc: 0.3449 - val_loss: 0.0693 - val_acc: 0.3401
# Epoch 6/10
# 16400/16461 [============================>.] - ETA: 0s - loss: 0.0681 - acc: 0.3465
# Epoch 00006: saving model to models/rnn_ae
# 16461/16461 [==============================] - 77s 5ms/step - loss: 0.0681 - acc: 0.3466 - val_loss: 0.0685 - val_acc: 0.3457
# Epoch 7/10
# 16400/16461 [============================>.] - ETA: 0s - loss: 0.0672 - acc: 0.3497
# Epoch 00007: saving model to models/rnn_ae
# 16461/16461 [==============================] - 76s 5ms/step - loss: 0.0672 - acc: 0.3497 - val_loss: 0.0675 - val_acc: 0.3478
# Epoch 8/10
# 16400/16461 [============================>.] - ETA: 0s - loss: 0.0666 - acc: 0.3516
# Epoch 00008: saving model to models/rnn_ae
# 16461/16461 [==============================] - 77s 5ms/step - loss: 0.0666 - acc: 0.3516 - val_loss: 0.0666 - val_acc: 0.3509
# Epoch 9/10
# 16400/16461 [============================>.] - ETA: 0s - loss: 0.0655 - acc: 0.3572
# Epoch 00009: saving model to models/rnn_ae
# 16461/16461 [==============================] - 80s 5ms/step - loss: 0.0655 - acc: 0.3572 - val_loss: 0.0664 - val_acc: 0.3513
# Epoch 10/10
# 16400/16461 [============================>.] - ETA: 0s - loss: 0.0649 - acc: 0.3591
# Epoch 00010: saving model to models/rnn_ae
# 16461/16461 [==============================] - 77s 5ms/step - loss: 0.0649 - acc: 0.3592 - val_loss: 0.0654 - val_acc: 0.3581

# %%
sent_2_sent(sents[27],sents[28],model,tokenizer=tokenizer)
# Out:
# from from from from from from from from car car car car car car car
# from from from from from from from from car car car car car car car
# from from from from from from from from car car car car car car car
# from from from from from from from car car car car car car car car
# from from from from from from from car car car car car car car car
# from from from from from from from car car car car car car car car
# from from from from from from from car car car car car car car car
# from from from from from from from car car car car car car car car
# from from from from from from car car car car car car car car car
# from from from from from from car car car car car car car car car
# from from from from from from car car car car car car car car car
# from from from from from from car car car car car car car car car
# from from from from from from car car car car car car car car car
# from from from from from car car car car car car car car car car
# from from from from from car car car car car car car car car car
# from from from from from car car car car car car car car car car
# from from from from from car car car car car car car car car car
# from from from from from car car car car car car car car car car
# from from from from from car car car car car car car car car car
# from from from from car car car car car car car car car car car
# from from from from car car car car car car car car car car car
# from from from from car car car car car car car car car car car
# from from from from car car car car car car car car car car car
# from from from from car car car car car car car car car car car
# from from from from car car car car car car car car car car car
# from from from from car car car car car car car car car car car
# from from from car car car car car car car car car car car car
# from from from car car car car car car car car car car car car
# from from from car car car car car car car car car car car car
# from from from car car car car car car car car car car car car
# from from from car car car car car car car car car car car car
# from from from car car car car car car car car car car car car
# from from from car car car car car car car car car car car car
# from from car car car car car car car car car car car car car
# from from car car car car car car car car car car car car car
# from from car car car car car car car car car car car car car
# from from car car car car car car car car car car car car car
# from from car car car car car car car car car car car car car
# each from car car car car car car car car car car car car car
# each from car car car car car car car car car car car car car
# each car car car car car car car car car car car car car car
# each car car car car car car car car car car car car car car
# each car car car car car car car car car car car car car car
# each car car car car car car car car car car car car car car
# each car car car car car car car car car car car car car car
# efforts car car car car car car car car car car car car car car
# efforts car car car car car car car car car car car car car car
# efforts car car car car car car car car car car car car car car
# efforts car car car car car car car car car car car car car car
# efforts car car car car car car car car car car car car car car
# efforts efforts car car car car car car car car car car car car car
# efforts efforts car car car car car car car car car car car car car
# efforts efforts car car car car car car car car car car car car car
# efforts efforts car car car car car car car car car car car car car
# efforts efforts car car car car car car car car car car car car car
# efforts efforts car car car car car car car car car car car car car
# efforts efforts car car car car car car car car car car car car car
# efforts efforts car car car car car car car car car car car car car
# efforts efforts car car car car car car car car car car car car car
# efforts efforts car car car car car car car car car car car car car
# efforts efforts efforts car car car car car car car car car car car car
# efforts efforts efforts car car car car car car car car car car car car
# efforts efforts efforts car car car car car car car car car car car car
# efforts efforts efforts car car car car car car car car car car car car
# efforts efforts efforts car car car car car car car car car car car car
# efforts efforts child child car car car car car car car car car car car
# efforts child child child child car car car car car car car car car car
# child child child child child car car car car car car car car car car
# child child child child child child car car car car car car car car car
# child child child child child child child car car car car car car car car
# child child child child child child child child child car car car car car car
# child child child child child child child child child child car car car car car
# child child child child child child child child child child child child car car car
# child child child child child child child child child child child child child child car
# child child child child child child child child child child child child child child child
# child child child child child child child child child child child child child child child
# child child child child child child child child child child child child child child child
# child child child child child child child child child child child child child child child
# child child child child child child child child child child child child child child child
# child child child child child child child child child child child child child child child
# child child child child child child your your child child child child child child child
# child child child child child your your your your your your child child child child
# child child child child your your your your your your your your your child child
# child child child child your your your your your your your your your your your
# child child child your your your your your your your your your your your your
# child child child your your your your your your your your your your your your
# child child child your your your your your your your your your your your your
# child child your your your your your your your your your your your your your
# child child your your your your your your your your your your your your your
# child child your your your your your your your your your your your your your
# child child your your your your your your your your your your your your your
# child child your your your your your your your your your your your your your
# child child your your your your your your your your your your your your your
# child child your your your your your your your your your your your your your
# child child your your your your your your your your your your your your your
# child child your your your your your your your your your your your your your
# child child your your your your your your your your your your your your your
# child your your your your your your your your your your your your your your
# child your your your your your your your your your your your your your your
# child your your your your your your your your your your your your your your

# %%
print(sents[27])
print(sents[29])
# Out:
# the couple was married aug. 2  1913 .
# attorneys for the mayor said that an amicable property settlement has been agreed upon .

# %%
sent1 = 'Explorer plugin open source'
_,a = sent_parse([sent1],tokenizer,build_indices=False)
z=model.encoder.predict(a)

# %%
deco=model.decoder.predict(z)

# %%
np.argmax(deco[0][1])
# Out:
# 414

# %%
words=[]
for seq in deco[0]:
    if len(seq):
        words.append(word_index.get(seq[np.argmax(seq)]))
    else:
        words.append(' ')
print(''.join(words))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-dea14b871cf6> in <module>()
#       5     else:
#       6         words.append(' ')
# ----> 7 print(''.join(words))
#
# TypeError: sequence item 0: expected str instance, NoneType found

# %%
index_word = {v: k for k, v in tokenizer.word_index.items()}
for seq in deco[0]:
    print(index_word[np.argmax(seq)])
# Out:
# tracked
# permanent
# permanent
# permanent
# permanent
# permanent
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html
# html

# %%
index_word
# Out:
# {1: 'the',
#  2: 'of',
#  3: 'to',
#  4: 'and',
#  5: 'in',
#  6: 'apt1',
#  7: 'is',
#  8: 'we',
#  9: 'a',
#  10: 'that',
#  11: '»»',
#  12: 'mandiant',
#  13: 'this',
#  14: 'our',
#  15: 'have',
#  16: 'china',
#  17: 'unit',
#  18: 'has',
#  19: 'are',
#  20: 'on',
#  21: 'cyber',
#  22: 'chinese',
#  23: 'from',
#  24: '61398',
#  25: 'as',
#  26: 'observed',
#  27: 'infrastructure',
#  28: 'espionage',
#  29: '1',
#  30: 'www',
#  31: 'report',
#  32: 'their',
#  33: 'an',
#  34: 'over',
#  35: 'computer',
#  36: 'at',
#  37: 'apt',
#  38: 'activity',
#  39: 'be',
#  40: 'by',
#  41: 'ip',
#  42: 'attack',
#  43: 'com',
#  44: 'based',
#  45: 'with',
#  46: 'operations',
#  47: 'which',
#  48: 'network',
#  49: 'for',
#  50: 'addresses',
#  51: '2013',
#  52: 'these',
#  53: 'its',
#  54: 'years',
#  55: 'it',
#  56: 'organization',
#  57: 'apt1’s',
#  58: 'shanghai',
#  59: 'pla',
#  60: 'used',
#  61: 'believe',
#  62: 'us',
#  63: 'them',
#  64: 'intelligence',
#  65: '6',
#  66: 'organizations',
#  67: 'groups',
#  68: 'one',
#  69: 'information',
#  70: 'large',
#  71: 'or',
#  72: 'industries',
#  73: 'security',
#  74: 'government',
#  75: 'activities',
#  76: 'access',
#  77: 'gsd',
#  78: 'department',
#  79: 'systems',
#  80: '−»',
#  81: 'cpc',
#  82: 'use',
#  83: 'u',
#  84: 's',
#  85: 'military',
#  86: 'january',
#  87: 'http',
#  88: '”',
#  89: 'hundreds',
#  90: 'attributed',
#  91: 'was',
#  92: 'three',
#  93: '3',
#  94: 'most',
#  95: 'operators',
#  96: 'against',
#  97: 'victims',
#  98: 'least',
#  99: 'scale',
#  100: 'directly',
#  101: 'four',
#  102: 'two',
#  103: 'new',
#  104: 'area',
#  105: 'there',
#  106: 'also',
#  107: 'language',
#  108: 'registered',
#  109: 'remote',
#  110: 'malware',
#  111: 'persona',
#  112: 'indicators',
#  113: 'economic',
#  114: '—',
#  115: '2011',
#  116: 'defense',
#  117: '4',
#  118: 'accessed',
#  119: 'since',
#  120: 'around',
#  121: 'world',
#  122: 'threat',
#  123: 'details',
#  124: 'about',
#  125: 'dozens',
#  126: 'however',
#  127: 'group',
#  128: 'conducted',
#  129: 'campaign',
#  130: 'pudong',
#  131: 'command',
#  132: 'behind',
#  133: 'china’s',
#  134: 'such',
#  135: 'support',
#  136: 'people’s',
#  137: 'liberation',
#  138: 'army',
#  139: 'pla’s',
#  140: '2nd',
#  141: 'bureau',
#  142: 'staff',
#  143: '3rd',
#  144: '61398’s',
#  145: 'personnel',
#  146: '141',
#  147: 'steal',
#  148: 'including',
#  149: 'other',
#  150: '5',
#  151: 'time',
#  152: 'into',
#  153: 'last',
#  154: 'desktop',
#  155: '614',
#  156: 'who',
#  157: 'enterprise',
#  158: 'will',
#  159: 'level',
#  160: 'they',
#  161: 'significant',
#  162: 'october',
#  163: 'attacks',
#  164: 'evidence',
#  165: 'house',
#  166: 'open',
#  167: 'gov',
#  168: 'february',
#  169: '2',
#  170: '2004',
#  171: 'breaches',
#  172: 'actors',
#  173: 'first',
#  174: 'aware',
#  175: 'more',
#  176: 'broad',
#  177: 'observations',
#  178: 'stolen',
#  179: 'likely',
#  180: 'unique',
#  181: 'networks',
#  182: 'actual',
#  183: 'keyboard',
#  184: 'extensive',
#  185: 'part',
#  186: 'research',
#  187: 'similar',
#  188: 'resources',
#  189: 'same',
#  190: 'known',
#  191: 'nature',
#  192: 'state',
#  193: 'central',
#  194: 'people',
#  195: 'communications',
#  196: 'english',
#  197: 'data',
#  198: 'intellectual',
#  199: 'property',
#  200: 'victim',
#  201: 'techniques',
#  202: 'not',
#  203: 'period',
#  204: '10',
#  205: 'countries',
#  206: 'identified',
#  207: 'strategic',
#  208: 'year',
#  209: '849',
#  210: 'distinct',
#  211: 'were',
#  212: 'fqdns',
#  213: '905',
#  214: 'provides',
#  215: 'system',
#  216: 'simplified',
#  217: 'using',
#  218: '000',
#  219: '“uglygorilla”',
#  220: 'his',
#  221: 'publicly',
#  222: '“dota”',
#  223: 'when',
#  224: 'communist',
#  225: 'party',
#  226: 'within',
#  227: 'subordinate',
#  228: 'commission',
#  229: '7',
#  230: 'united',
#  231: 'states',
#  232: 'allies',
#  233: 'europe',
#  234: 'asia',
#  235: 'beijing',
#  236: 'put',
#  237: 'stop',
#  238: 'all',
#  239: 'should',
#  240: 'combined',
#  241: 'rogers',
#  242: 'without',
#  243: 'any',
#  244: 'hearing',
#  245: 'ongoing',
#  246: 'documents',
#  247: 'pdf',
#  248: '“chinese',
#  249: 'hackers',
#  250: 'suspected',
#  251: 'computers',
#  252: 'feb',
#  253: 'business',
#  254: 'technology',
#  255: 'html',
#  256: 'majority',
#  257: 'persistent',
#  258: 'may',
#  259: 'but',
#  260: 'way',
#  261: 'analyzed',
#  262: 'prolific',
#  263: 'than',
#  264: '20',
#  265: 'single',
#  266: 'range',
#  267: '2006',
#  268: 'sheer',
#  269: 'impact',
#  270: 'represents',
#  271: 'only',
#  272: 'small',
#  273: 'fraction',
#  274: 'visibility',
#  275: 'seven',
#  276: 'back',
#  277: 'control',
#  278: 'tools',
#  279: 'effort',
#  280: 'underscore',
#  281: 'individuals',
#  282: 'revealing',
#  283: 'personas',
#  284: 'following',
#  285: 'given',
#  286: 'able',
#  287: 'direct',
#  288: 'mission',
#  289: 'capabilities',
#  290: 'located',
#  291: 'source',
#  292: 'general',
#  293: '总参三部二局',
#  294: '61398部队',
#  295: 'work',
#  296: 'secret',
#  297: 'situated',
#  298: '130',
#  299: 'facility',
#  300: '12',
#  301: 'high',
#  302: 'estimate',
#  303: 'thousands',
#  304: 'size',
#  305: 'national',
#  306: 'requires',
#  307: 'where',
#  308: 'terabytes',
#  309: 'compromise',
#  310: 'well',
#  311: 'designed',
#  312: 'victim’s',
#  313: 'several',
#  314: 'months',
#  315: 'uses',
#  316: 'email',
#  317: 'maintained',
#  318: 'days',
#  319: 'ten',
#  320: 'month',
#  321: 'operating',
#  322: 'different',
#  323: 'therefore',
#  324: 'establishing',
#  325: 'do',
#  326: 'intrusion',
#  327: 'servers',
#  328: '13',
#  329: 'fully',
#  330: 'domain',
#  331: 'names',
#  332: 'confirmed',
#  333: 'instances',
#  334: 'logging',
#  335: '832',
#  336: 'tool',
#  337: '97',
#  338: 'intruders',
#  339: 'set',
#  340: 'sessions',
#  341: 'setting',
#  342: 'client',
#  343: 'attackers',
#  344: 'transmit',
#  345: 'htran',
#  346: 'between',
#  347: '8',
#  348: 'volume',
#  349: 'duration',
#  350: 'would',
#  351: 'need',
#  352: 'requestors',
#  353: 'been',
#  354: 'registering',
#  355: 'campaigns',
#  356: 'accounts',
#  357: 'while',
#  358: 'families',
#  359: 'location',
#  360: 'specifically',
#  361: 'digital',
#  362: 'redline',
#  363: 'can',
#  364: 'mainland',
#  365: 'decision',
#  366: 'risk',
#  367: 'always',
#  368: 'understanding',
#  369: 'hope',
#  370: 'publishing',
#  371: 'tracking',
#  372: 'tasking',
#  373: 'unit’s',
#  374: 'owned',
#  375: 'senior',
#  376: 'rand',
#  377: '2012',
#  378: 'uscc',
#  379: 'bureaus',
#  380: 'sits',
#  381: '\ufeff“china’s',
#  382: 'reached',
#  383: 'intolerable',
#  384: 'i',
#  385: 'obligation',
#  386: 'confront',
#  387: 'demand',
#  388: 'piracy',
#  389: 'waging',
#  390: 'massive',
#  391: 'trade',
#  392: 'war',
#  393: 'band',
#  394: 'together',
#  395: 'pressure',
#  396: 'diplomatic',
#  397: 'leverage',
#  398: 'advantage',
#  399: 'end',
#  400: 'scourge',
#  401: '”1',
#  402: 'rep',
#  403: 'mike',
#  404: '“it',
#  405: 'unprofessional',
#  406: 'groundless',
#  407: 'accuse',
#  408: 'launching',
#  409: 'conclusive',
#  410: '”2',
#  411: 'ministry',
#  412: '“mike',
#  413: 'statement',
#  414: 'permanent',
#  415: 'select',
#  416: 'committee',
#  417: 'threats',
#  418: 'efforts',
#  419: 'protect',
#  420: 'nation',
#  421: 'sites',
#  422: 'files',
#  423: '100411cyberhearingrogers',
#  424: 'post’s',
#  425: 'washington',
#  426: 'post',
#  427: 'washingtonpost',
#  428: 'posts',
#  429: '02',
#  430: '01',
#  431: 'd5a44fde',
#  432: '6cb1',
#  433: '11e2',
#  434: 'bd36',
#  435: 'c0fe61a205f6',
#  436: 'story',
#  437: 'executive',
#  438: 'summary',
#  439: 'investigated',
#  440: 'advanced',
#  441: 'referred',
#  442: '“advanced',
#  443: 'threat”',
#  444: 'published',
#  445: '2010',
#  446: 'm',
#  447: 'trends',
#  448: 'stated',
#  449: 'position',
#  450: '“the',
#  451: 'authorize',
#  452: 'there’s',
#  453: 'no',
#  454: 'determine',
#  455: 'extent',
#  456: 'involvement',
#  457: 'now',
#  458: 'later',
#  459: 'required',
#  460: 'change',
#  461: 'assessment',
#  462: 'during',
#  463: 'investigations',
#  464: 'convince',
#  465: 'conducting',
#  466: 'primarily',
#  467: 'continues',
#  468: 'track',
#  469: 'focused',
#  470: 'refer',
#  471: '“apt1”',
#  472: 'origins',
#  473: 'terms',
#  474: 'quantity',
#  475: 'compelled',
#  476: 'write',
#  477: 'though',
#  478: 'incomplete',
#  479: 'group’s',
#  480: 'intrusions',
#  481: 'nearly',
#  482: '150',
#  483: 'vantage',
#  484: 'point',
#  485: 'responding',
#  486: 'tracked',
#  487: 'allocated',
#  488: 'uncovered',
#  489: 'substantial',
#  490: 'amount',
#  491: 'modus',
#  492: 'operandi',
#  493: 'tactics',
#  494: 'procedures',
#  495: 'like',
#  496: 'soldiers',
#  497: 'merely',
#  498: 'orders',
#  499: 'others',
#  500: 'analysis',
#  501: 'led',
#  502: 'conclude',
#  503: 'sponsored',
#  504: 'wage',
#  505: 'long',
#  506: 'running',
#  507: 'because',
#  508: 'receives',
#  509: 'seeking',
#  510: 'identify',
#  511: 'found',
#  512: 'precisely',
#  513: 'appears',
#  514: 'originate',
#  515: 'conclusions',
#  516: 'exclusively',
#  517: 'unclassified',
#  518: 'derived',
#  519: 'none',
#  520: 'involves',
#  521: 'confirmation',
#  522: 'classified',
#  523: 'key',
#  524: 'findings',
#  525: 'believed',
#  526: 'department’s',
#  527: 'commonly',
#  528: 'cover',
#  529: 'designator',
#  530: 'mucd',
#  531: '“unit',
#  532: '61398’s”',
#  533: 'considered',
#  534: 'engages',
#  535: 'harmful',
#  536: '“computer',
#  537: 'partially',
#  538: 'datong',
#  539: 'road',
#  540: '大同路',
#  541: 'gaoqiaozhen',
#  542: '高桥镇',
#  543: '浦东新区',
#  544: '上海',
#  545: 'building',
#  546: 'compound',
#  547: '663',
#  548: 'square',
#  549: 'foot',
#  550: 'stories',
#  551: 'built',
#  552: 'early',
#  553: '2007',
#  554: 'staffed',
#  555: 'perhaps',
#  556: 'physical',
#  557: 'telecom',
#  558: 'provided',
#  559: 'special',
#  560: 'fiber',
#  561: 'optic',
#  562: 'name',
#  563: 'trained',
#  564: 'proficient',
#  565: 'traced',
#  566: 'serve',
#  567: 'systematically',
#  568: 'demonstrated',
#  569: 'capability',
#  570: 'intent',
#  571: 'simultaneously',
#  572: 'companies',
#  573: 'spanning',
#  574: 'major',
#  575: 'defined',
#  576: 'methodology',
#  577: 'honed',
#  578: 'volumes',
#  579: 'valuable',
#  580: 'once',
#  581: 'established',
#  582: 'periodically',
#  583: 'revisit',
#  584: 'categories',
#  585: 'blueprints',
#  586: 'proprietary',
#  587: 'manufacturing',
#  588: 'processes',
#  589: 'test',
#  590: 'results',
#  591: 'plans',
#  592: 'pricing',
#  593: 'partnership',
#  594: 'agreements',
#  595: 'emails',
#  596: 'contact',
#  597: 'lists',
#  598: 'organizations’',
#  599: 'leadership',
#  600: 'some',
#  601: 'yet',
#  602: 'being',
#  603: 'utilities',
#  604: 'getmail',
#  605: 'mapiget',
#  606: 'average',
#  607: '356',
#  608: 'longest',
#  609: '764',
#  610: 'among',
#  611: 'thefts',
#  612: 'stealing',
#  613: 'compressed',
#  614: 'successfully',
#  615: 'compromised',
#  616: '17',
#  617: 'lower',
#  618: 'bounds',
#  619: '91',
#  620: 'remaining',
#  621: 'cases',
#  622: 'either',
#  623: 'else',
#  624: 'date',
#  625: 'focuses',
#  626: 'compromising',
#  627: 'across',
#  628: 'speaking',
#  629: '87',
#  630: 'headquartered',
#  631: 'native',
#  632: 'targets',
#  633: 'match',
#  634: 'growth',
#  635: 'emerging',
#  636: '12th',
#  637: 'five',
#  638: 'plan',
#  639: 'maintains',
#  640: 'controls',
#  641: 'establish',
#  642: 'minimum',
#  643: '937',
#  644: 'c2',
#  645: 'hosted',
#  646: '709',
#  647: 'followed',
#  648: '109',
#  649: 'qualified',
#  650: 'resolving',
#  651: '988',
#  652: 'user',
#  653: 'interactive',
#  654: 'graphical',
#  655: 'interface',
#  656: '551',
#  657: 'times',
#  658: 'connecting',
#  659: 'under',
#  660: 'observation',
#  661: 'operator’s',
#  662: 'layout',
#  663: 'keyboard”',
#  664: 'microsoft’s',
#  665: 'configures',
#  666: 'automatically',
#  667: 'selected',
#  668: 'microsoft®',
#  669: 'configured',
#  670: 'display',
#  671: 'fonts',
#  672: '817',
#  673: '98',
#  674: 'controlled',
#  675: 'resolved',
#  676: '767',
#  677: 'separate',
#  678: '“huc',
#  679: 'packet',
#  680: 'tool”',
#  681: 'communicate',
#  682: 'routable',
#  683: 'victims’',
#  684: '100',
#  685: '613',
#  686: '99',
#  687: 'net',
#  688: 'blocks',
#  689: 'implies',
#  690: 'potentially',
#  691: 'human',
#  692: 'conservatively',
#  693: 'current',
#  694: 'includes',
#  695: 'type',
#  696: 'supported',
#  697: 'linguists',
#  698: 'researchers',
#  699: 'authors',
#  700: 'industry',
#  701: 'experts',
#  702: 'translate',
#  703: 'task',
#  704: 'requests',
#  705: 'then',
#  706: 'sizable',
#  707: 'dedicated',
#  708: 'acquiring',
#  709: 'maintaining',
#  710: 'equipment',
#  711: 'handle',
#  712: 'finances',
#  713: 'management',
#  714: 'logistics',
#  715: 'e',
#  716: 'g',
#  717: 'shipping',
#  718: 'associated',
#  719: 'active',
#  720: 'include',
#  721: 'domains',
#  722: 'authoring',
#  723: 'expressed',
#  724: 'interest',
#  725: '“cyber',
#  726: 'troops”',
#  727: 'second',
#  728: 'actor',
#  729: 'call',
#  730: 'conduct',
#  731: 'social',
#  732: 'engineering',
#  733: 'spear',
#  734: 'phishing',
#  735: 'phone',
#  736: 'number',
#  737: 'both',
#  738: 'shared',
#  739: 'ranges',
#  740: 'third',
#  741: 'nickname',
#  742: '“superhard',
#  743: 'creator',
#  744: 'contributor',
#  745: 'auriga',
#  746: 'bangat',
#  747: '“superhard”',
#  748: 'discloses',
#  749: 'releasing',
#  750: 'bolster',
#  751: 'defenses',
#  752: 'providing',
#  753: 'delivery',
#  754: 'md5',
#  755: 'hashes',
#  756: 'sample',
#  757: 'iocs',
#  758: 'detailed',
#  759: 'descriptions',
#  760: '40',
#  761: 'arsenal',
#  762: 'weapons',
#  763: 'thirteen',
#  764: 'x',
#  765: '509',
#  766: 'encryption',
#  767: 'certificates',
#  768: 'compilation',
#  769: 'videos',
#  770: 'showing',
#  771: 'attacker',
#  772: 'existing',
#  773: 'customers',
#  774: 'mandiant’s',
#  775: 'products',
#  776: 'managed',
#  777: 'intelligent',
#  778: 'response®',
#  779: 'had',
#  780: 'prior',
#  781: 'making',
#  782: 'available',
#  783: 'redlinetm',
#  784: 'free',
#  785: 'host',
#  786: 'investigative',
#  787: 'downloaded',
#  788: 'download',
#  789: 'conclusion',
#  790: 'sustained',
#  791: 'wide',
#  792: 'singularly',
#  793: 'leaves',
#  794: 'little',
#  795: 'doubt',
#  796: 'totality',
#  797: 'provide',
#  798: 'document',
#  799: 'bolsters',
#  800: 'claim',
#  801: 'admit',
#  802: 'unlikely',
#  803: 'possibility',
#  804: 'resourced',
#  805: 'full',
#  806: 'speakers',
#  807: 'telecommunications',
#  808: 'engaged',
#  809: 'multi',
#  810: 'right',
#  811: 'outside',
#  812: 'gates',
#  813: 'performing',
#  814: 'tasks',
#  815: 'why',
#  816: 'exposing',
#  817: 'publish',
#  818: 'painstaking',
#  819: 'what',
#  820: 'started',
#  821: '“what',
#  822: 'if”',
#  823: 'discussion',
#  824: 'traditional',
#  825: 'non',
#  826: 'disclosure',
#  827: 'policy',
#  828: 'quickly',
#  829: 'turned',
#  830: 'realization',
#  831: 'positive',
#  832: 'resulting',
#  833: 'expose',
#  834: 'outweighed',
#  835: 'ability',
#  836: 'collect',
#  837: 'particular',
#  838: 'acknowledge',
#  839: 'originating',
#  840: 'wanted',
#  841: 'arm',
#  842: 'prepare',
#  843: 'professionals',
#  844: 'combat',
#  845: 'effectively',
#  846: 'issue',
#  847: 'attribution',
#  848: 'missing',
#  849: 'link',
#  850: 'landscape',
#  851: 'solid',
#  852: 'connection',
#  853: 'room',
#  854: 'observers',
#  855: 'dismiss',
#  856: 'actions',
#  857: 'uncoordinated',
#  858: 'solely',
#  859: 'criminal',
#  860: 'peripheral',
#  861: 'larger',
#  862: 'global',
#  863: 'concerns',
#  864: 'lead',
#  865: 'increased',
#  866: 'coordinated',
#  867: 'action',
#  868: 'countering',
#  869: 'downsides',
#  870: 'many',
#  871: 'technologies',
#  872: 'described',
#  873: 'vastly',
#  874: 'effective',
#  875: 'additionally',
#  876: 'certain',
#  877: 'kinds',
#  878: 'dramatically',
#  879: 'shortens',
#  880: 'lifespan',
#  881: 'changes',
#  882: 'after',
#  883: 'reading',
#  884: 'undoubtedly',
#  885: 'force',
#  886: 'harder',
#  887: 'continue',
#  888: 'accuracy',
#  889: 'sincere',
#  890: 'temporarily',
#  891: 'increase',
#  892: 'costs',
#  893: 'impede',
#  894: 'progress',
#  895: 'meaningful',
#  896: 'acutely',
#  897: 'poses',
#  898: 'expect',
#  899: 'reprisals',
#  900: 'onslaught',
#  901: 'criticism',
#  902: 'indicate',
#  903: '中国共产党',
#  904: '中国人民解放军',
#  905: 'commit',
#  906: 'systematic',
#  907: 'theft',
#  908: 'section',
#  909: 'photos',
#  910: 'facilities',
#  911: 'references',
#  912: 'discussing',
#  913: 'training',
#  914: 'coursework',
#  915: 'requirements',
#  916: 'internal',
#  917: 'documenting',
#  918: 'relationship',
#  919: 'particularly',
#  920: 'relevant',
#  921: 'discuss',
#  922: 'expertise',
#  923: 'parallel',
#  924: 'those',
#  925: 'institutionalized',
#  926: 'draw',
#  927: 'upon',
#  928: 'enterprises',
#  929: 'ultimate',
#  930: 'authority',
#  931: 'unlike',
#  932: 'western',
#  933: 'societies',
#  934: 'political',
#  935: 'parties',
#  936: 'fact',
#  937: 'reports',
#  938: 'cpc’s',
#  939: 'cmc',
#  940: '中央军事委',
#  941: '员会',
#  942: 'means',
#  943: 'occurring',
#  944: 'direction',
#  945: 'members',
#  946: '总参谋',
#  947: '部',
#  948: '总参三部',
#  949: 'joint',
#  950: 'chiefs',
#  951: 'establishes',
#  952: 'doctrine',
#  953: 'operational',
#  954: 'guidance',
#  955: 'focus',
#  956: 'signals',
#  957: 'foreign',
#  958: 'proficiency',
#  959: 'james',
#  960: 'c',
#  961: 'mulvenon',
#  962: 'andrew',
#  963: 'n',
#  964: 'd',
#  965: 'yang',
#  966: 'editors',
#  967: 'reference',
#  968: 'v1',
#  969: '0',
#  970: 'santa',
#  971: 'monica',
#  972: 'ca',
#  973: 'corporation',
#  974: '2002',
#  975: '96',
#  976: 'org',
#  977: 'pubs',
#  978: 'conf',
#  979: 'proceedings',
#  980: 'cf182',
#  981: 'bryan',
#  982: 'krekel',
#  983: 'patton',
#  984: 'adams',
#  985: 'george',
#  986: 'bakos',
#  987: '“occupying',
#  988: 'ground',
#  989: 'prepared',
#  990: 'review',
#  991: 'northrop',
#  992: 'grumman',
#  993: 'corp',
#  994: 'rfp',
#  995: '20report',
#  996: 'capabilitiesforcomputer',
#  997: 'networkoperationsandcyberespionage',
#  998: 'estimated',
#  999: '0009',
#  1000: 'divided',
#  ...}
